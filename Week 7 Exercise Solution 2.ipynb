# %%
# pick a random integer from 1 to 100 and assign it to a variable

help(sample)

# %%
sample(1:100)
# Out:
#   [1]  35  94  71  25  79  22  39  83  67  47  91  23  32  82  73  24  72  51
#  [19]  57   1  84  10  36  31   9  50  80  27  37  58  89  74   5  62   7  92
#  [37]  85  63  53  21  45  49  19  88  29  33  77  98   4   6   2  43  96  54
#  [55]  34  68  66  76  12  81  78  52  18  14  26  97  69  48  56  70  38  16
#  [73]   8  87  90  75  55  11  46  93  86  13  30  59  65  44  99  42 100   3
#  [91]  60  17  20  61  41  28  95  40  64  15

# %%
num = sample(1:100)

# %%
# print an introduction to the game and explain the rules
print("WELCOME TO GUESS ME!")
print("I'm thinking of a number between 1 and 100")
print("If your guess is more than 10 away from my number, I'll tell you you're COLD")
print("If your guess is within 10 of my number, I'll tell you you're WARM")
print("If your guess is farther than your most recent guess, I'll say you're getting COLDER")
print("If your guess is closer than your most recent guess, I'll say you're getting WARMER")
print("LET'S PLAY!")
# Out:
# [1] "WELCOME TO GUESS ME!"
# [1] "I'm thinking of a number between 1 and 100"
# [1] "If your guess is more than 10 away from my number, I'll tell you you're COLD"
# [1] "If your guess is within 10 of my number, I'll tell you you're WARM"
# [1] "If your guess is farther than your most recent guess, I'll say you're getting COLDER"
# [1] "If your guess is closer than your most recent guess, I'll say you're getting WARMER"
# [1] "LET'S PLAY!"

# %%
# Create a list to store guesses

guesses =(0)
guesses
# Out:
# [1] 0

# %%
# Write a while loop that asks for a valid guess. Test it a few times to make sure it works
while (TRUE){
    GuessANumner = as.integer(readline(prompt="Guess a number between 1 and 100.\n What is your guess?"))
    if (GuessANumber < 1| GuessANumber > 100){
        message ("OUT OF BOUNDS. Please Try Again")
        next
    }
    break
}

# %%
#Write a while loop that compares the player's guess to our number. If the player guesses correctly, break from the loop. Otherwise, tell the player if they're warmer or colder, and continue asking for guesses

while(TRUE){
    GuessANumber=as.integer(readline(prompt="Guess a number between 1 and 100.\n What is your guess?"))
}if (GuessANumber <1 | GuessANumber > 100){
    message("OUT OF BOUNDS. Please Try Again:")
    next
}if (GuessANumber == num){
    message(sprintf("Congratulations. You guesses the number in %s guesses!", length(guesses)))
    break
}
